# %% [markdown]
# # Path Planning Algorithm Performance Comparison
#
# This notebook provides comprehensive analysis and comparison of different path planning algorithms implemented in the Week 2 project.
#
# ## Algorithms Covered:
# - A* Path Planning
# - RRT (Rapidly-exploring Random Tree)
# - RRT* (Optimal RRT)
# - Dynamic RRT (for traffic scenarios)
#
# ## Analysis Includes:
# - Performance metrics comparison
# - Success rates across different scenarios
# - Path quality analysis
# - Computational efficiency
# - Visualization of results

# %%
import sys
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from pathlib import Path

# Add parent directory to path
sys.path.append(str(Path.cwd().parent))

# Import our modules
from compare_planners import PlannerComparison
from utils.visualization import PathVisualizer
from utils.data_logger import PathPlanningLogger

# Set up plotting style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

print("Imports completed successfully!")

# %% [markdown]
# ## Load Comparison Results
#
# Load results from previous algorithm comparison runs.

# %%
# Load comparison results
results_dir = Path('../output_data/day14_comparisons')

try:
    with open(results_dir / 'comparison_results.pkl', 'rb') as f:
        comparison_results = pickle.load(f)
    
    with open(results_dir / 'comparison_analysis.pkl', 'rb') as f:
        analysis_results = pickle.load(f)
    
    print(f"Loaded {len(comparison_results)} comparison results")
    print(f"Analysis covers {len(analysis_results)} algorithms")
    
except FileNotFoundError:
    print("No existing results found. Running new comparison...")
    
    # Run new comparison
    comparison = PlannerComparison()
    comparison_results = comparison.run_comprehensive_comparison(num_runs=3)
    analysis_results = comparison.analyze_results()
    
    print("New comparison completed!")
